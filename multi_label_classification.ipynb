# %%
import pandas as pd
from sklearn.model_selection import train_test_split

# %%
df = pd.read_csv('preprocessed_dataset.csv')
df.head()
# Out:
#                        id                                               text  \
# 0  28C2BJvmEsQKiS4AEO2eIE  ['за', 'период', 'с', 'сентября', '2017', 'год...
# 1  65s7gPkLFmgkeIQQWCCcWW  ['также', 'аналитики', 'knight', 'frank', 'про...
# 2  2ldCvrzcf6wcwOMwiI2A4U  ['несмотря', 'на', 'то', 'что', 'основные', 'э...
# 3   SlQ8gdBQCiQwgUuQMaY0g  ['россия', 'обладает', 'мощным', 'сегментом', ...
# 4  5KWOefdhVC8ai4qQOmCoco  ['доля', 'свободных', 'офисных', 'площадей', '...
#
#                               classes  \
# 0                            ['FMCG']
# 1        ['Недвижимость', 'Хранение']
# 2                            ['FMCG']
# 3  ['FMCG', 'Пищевая промышленность']
# 4                    ['Недвижимость']
#
#                                           text_final  FMCG  HoReCa  \
# 0  период сентябрь 2017 год октябрь 2018 год росс...     1       0
# 1  также аналитика knight frank прогнозировать ко...     0       0
# 2  несмотря основной экономический показатель нах...     1       0
# 3  россия обладать мощный сегмент хлебопекарный п...     1       0
# 4  доля свободный офисный площадь уменьшиться ква...     0       0
#
#    Автомобили, мотоциклы  Аптеки  Банковские, финансовые услуги  \
# 0                      0       0                              0
# 1                      0       0                              0
# 2                      0       0                              0
# 3                      0       0                              0
# 4                      0       0                              0
#
#    Бытовая и цифровая техника  ...  Сенсорные технологии  Строительство  \
# 0                           0  ...                     0              0
# 1                           0  ...                     0              0
# 2                           0  ...                     0              0
# 3                           0  ...                     0              0
# 4                           0  ...                     0              0
#
#    Телефония  Товары для животных  Услуги по доставке, курьерские услуги  \
# 0          0                    0                                      0
# 1          0                    0                                      0
# 2          0                    0                                      0
# 3          0                    0                                      0
# 4          0                    0                                      0
#
#    Фармацевтика  Финансовые, банковские услуги  Химическая промышленность  \
# 0             0                              0                          0
# 1             0                              0                          0
# 2             0                              0                          0
# 3             0                              0                          0
# 4             0                              0                          0
#
#    Хранение  Частная медицина
# 0         0                 0
# 1         1                 0
# 2         0                 0
# 3         0                 0
# 4         0                 0
#
# [5 rows x 37 columns]

# %% [markdown]
# ### Формирование обучающей и тестовой выборки

# %%
train, test = train_test_split(df, random_state=42, test_size=0.33, shuffle=True)

# %%
X_train = train.text_final
X_test = test.text_final

# %%
print(X_train.shape)
print(X_test.shape)
# Out:
# (91,)
# (46,)

# %%
train_text = train['text_final']
test_text = test['text_final']

# %% [markdown]
# ### Формирование векторов для обучения

# %%
from sklearn.feature_extraction.text import TfidfVectorizer

# Преобразование данных из таблицы в вектор свойств TF-IDF
vectorizer = TfidfVectorizer(strip_accents='unicode', analyzer='word', ngram_range=(1,3), norm='l2')
vectorizer.fit(train_text)
vectorizer.fit(test_text)
# Out:
# TfidfVectorizer(analyzer='word', binary=False, decode_error='strict',
#         dtype=<class 'numpy.float64'>, encoding='utf-8', input='content',
#         lowercase=True, max_df=1.0, max_features=None, min_df=1,
#         ngram_range=(1, 3), norm='l2', preprocessor=None, smooth_idf=True,
#         stop_words=None, strip_accents='unicode', sublinear_tf=False,
#         token_pattern='(?u)\\b\\w\\w+\\b', tokenizer=None, use_idf=True,
#         vocabulary=None)

# %%
x_train = vectorizer.transform(train_text)
y_train = train.drop(labels = ['id', 'text', 'text_final', 'classes'], axis=1)

x_test = vectorizer.transform(test_text)
y_test = test.drop(labels = ['id', 'text', 'text_final', 'classes'], axis=1)

# %%
x_train
# Out:
# <91x47893 sparse matrix of type '<class 'numpy.float64'>'
# 	with 26038 stored elements in Compressed Sparse Row format>

# %%
y_train[:10]
# Out:
#     FMCG  HoReCa  Автомобили, мотоциклы  Аптеки  \
# 15     0       0                      0       0
# 86     0       0                      0       0
# 39     0       0                      0       0
# 22     0       0                      1       0
# 55     0       0                      0       0
# 73     0       0                      0       0
# 97     0       1                      0       0
# 47     1       0                      0       0
# 30     1       0                      0       0
# 80     1       0                      0       0
#
#     Банковские, финансовые услуги  Бытовая и цифровая техника  \
# 15                              0                           0
# 86                              0                           0
# 39                              0                           0
# 22                              1                           0
# 55                              0                           0
# 73                              0                           0
# 97                              0                           0
# 47                              0                           0
# 30                              0                           0
# 80                              0                           0
#
#     Деревообработка  Инвестиции  Интернет-торговля  Кадры  ...  \
# 15                0           0                  0      0  ...
# 86                0           0                  1      0  ...
# 39                0           0                  0      1  ...
# 22                0           0                  0      0  ...
# 55                0           0                  0      0  ...
# 73                0           0                  0      0  ...
# 97                0           0                  0      0  ...
# 47                0           0                  0      0  ...
# 30                0           0                  0      0  ...
# 80                0           0                  0      0  ...
#
#     Сенсорные технологии  Строительство  Телефония  Товары для животных  \
# 15                     0              0          0                    0
# 86                     0              0          0                    0
# 39                     0              0          0                    0
# 22                     0              0          0                    0
# 55                     0              0          0                    0
# 73                     0              0          0                    0
# 97                     0              0          0                    0
# 47                     0              0          0                    0
# 30                     0              0          0                    0
# 80                     0              0          0                    0
#
#     Услуги по доставке, курьерские услуги  Фармацевтика  \
# 15                                      0             0
# 86                                      0             0
# 39                                      0             0
# 22                                      0             0
# 55                                      0             0
# 73                                      0             0
# 97                                      0             0
# 47                                      0             0
# 30                                      0             0
# 80                                      0             0
#
#     Финансовые, банковские услуги  Химическая промышленность  Хранение  \
# 15                              0                          0         0
# 86                              0                          0         0
# 39                              0                          0         0
# 22                              0                          0         0
# 55                              0                          0         0
# 73                              0                          0         0
# 97                              0                          0         0
# 47                              0                          0         0
# 30                              0                          0         0
# 80                              0                          0         0
#
#     Частная медицина
# 15                 0
# 86                 0
# 39                 0
# 22                 0
# 55                 0
# 73                 0
# 97                 0
# 47                 0
# 30                 0
# 80                 0
#
# [10 rows x 33 columns]

# %%
categories = list(df.columns.values)
categories = categories[4:]
categories
# Out:
# ['FMCG',
#  'HoReCa',
#  'Автомобили, мотоциклы',
#  'Аптеки',
#  'Банковские, финансовые услуги',
#  'Бытовая и цифровая техника',
#  'Деревообработка',
#  'Инвестиции',
#  'Интернет-торговля',
#  'Кадры',
#  'Лесное хозяйство',
#  'Мебель, товары для дома и ремонта',
#  'Напитки',
#  'Недвижимость',
#  'Одежда, обувь, аксессуары',
#  'Пищевая промышленность',
#  'Программное обеспечение',
#  'Производство транспортных средств',
#  'Промышленное оборудование',
#  'Растениеводство',
#  'Реклама',
#  'Рестораны',
#  'Салоны красоты и SPA',
#  'Сенсорные технологии',
#  'Строительство',
#  'Телефония',
#  'Товары для животных',
#  'Услуги по доставке, курьерские услуги',
#  'Фармацевтика',
#  'Финансовые, банковские услуги',
#  'Химическая промышленность',
#  'Хранение',
#  'Частная медицина']

# %% [markdown]
# ### Задача классификации

# %% [markdown]
# Задача относится к классификации по нескольким меткам (Multi Label Text Classification).
# Метки не являются взаимоисключающими.

# %% [markdown]
# Существует два основных метода решения проблемы классификации по нескольким меткам:
# методы преобразования проблем и методы адаптации алгоритмов.
#
# Методы преобразования задач преобразуют проблему с несколькими метками в набор задач двоичной классификации,
# которые затем могут быть обработаны с использованием классификаторов одного класса.

# %% [markdown]
# ### Логистическая регрессия (OneVsRest)

# %% [markdown]
# https://scikit-learn.org/stable/modules/generated/sklearn.multiclass.OneVsRestClassifier.html
#
# или метод бинарной релевантности.
#
# Каждая метка представлена своим собственным классификатором и обучение всех классификаторов проводится независимо друг от друга. Это наиболее часто используемая стратегия для multiclass и multilabel классификации и является справедливым выбором по умолчанию.

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.pipeline import Pipeline
from sklearn.metrics import accuracy_score
from sklearn.multiclass import OneVsRestClassifier

# %%
LogReg_pipeline = Pipeline([
    ('clf', OneVsRestClassifier(LogisticRegression(solver='sag'), n_jobs=-1)),
])

for category in categories:
    print('**Processing {} comments...**'.format(category))
    
    # Тренировка модели
    LogReg_pipeline.fit(x_train, train[category])
    
    # вычисление точности
    prediction = LogReg_pipeline.predict(x_test)
    print('Test accuracy is {}'.format(accuracy_score(test[category], prediction)))
    print("\n")
# Out:
# **Processing FMCG comments...**
# Test accuracy is 0.6956521739130435
#
#
# **Processing HoReCa comments...**
# Test accuracy is 0.9782608695652174
#
#
# **Processing Автомобили, мотоциклы comments...**
# Test accuracy is 1.0
#
#
# **Processing Аптеки comments...**
# Test accuracy is 1.0
#
#
# **Processing Банковские, финансовые услуги comments...**
# Test accuracy is 0.8913043478260869
#
#
# **Processing Бытовая и цифровая техника comments...**
# Test accuracy is 0.9565217391304348
#
#
# **Processing Деревообработка comments...**
# Test accuracy is 1.0
#
#
# **Processing Инвестиции comments...**
# Test accuracy is 0.9782608695652174
#
#
# **Processing Интернет-торговля comments...**
# Test accuracy is 0.8043478260869565
#
#
# **Processing Кадры comments...**
# Test accuracy is 1.0
#
#
# **Processing Лесное хозяйство comments...**
# Test accuracy is 1.0
#
#
# **Processing Мебель, товары для дома и ремонта comments...**
# Test accuracy is 1.0
#
#
# **Processing Напитки comments...**
# Test accuracy is 1.0
#
#
# **Processing Недвижимость comments...**
# Test accuracy is 0.6956521739130435
#
#
# **Processing Одежда, обувь, аксессуары comments...**
# Test accuracy is 0.9565217391304348
#
#
# **Processing Пищевая промышленность comments...**
# Test accuracy is 0.9347826086956522
#
#
# **Processing Программное обеспечение comments...**
# Test accuracy is 1.0
#
#
# **Processing Производство транспортных средств comments...**
# Test accuracy is 1.0
#
#
# **Processing Промышленное оборудование comments...**
# Test accuracy is 1.0
#
#
# **Processing Растениеводство comments...**
# Test accuracy is 1.0
#
#
# **Processing Реклама comments...**
# Test accuracy is 0.9782608695652174
#
#
# **Processing Рестораны comments...**
# Test accuracy is 1.0
#
#
# **Processing Салоны красоты и SPA comments...**
# Test accuracy is 1.0
#
#
# **Processing Сенсорные технологии comments...**
# Test accuracy is 0.9782608695652174
#
#
# **Processing Строительство comments...**
# Test accuracy is 0.9782608695652174
#
#
# **Processing Телефония comments...**
# Test accuracy is 0.9782608695652174
#
#
# **Processing Товары для животных comments...**
# Test accuracy is 0.9782608695652174
#
#
# **Processing Услуги по доставке, курьерские услуги comments...**
# Test accuracy is 1.0
#
#
# **Processing Фармацевтика comments...**
# Test accuracy is 1.0
#
#
# **Processing Финансовые, банковские услуги comments...**
# Test accuracy is 0.9782608695652174
#
#
# **Processing Химическая промышленность comments...**
# Test accuracy is 1.0
#
#
# **Processing Хранение comments...**
# Test accuracy is 1.0
#
#
# **Processing Частная медицина comments...**
# Test accuracy is 0.9782608695652174

# %% [markdown]
# ### Multiple Binary Classifications

# %% [markdown]
# http://scikit.ml/api/skmultilearn.problem_transform.br.html
#
# BinaryRelevance преобразует задачу классификации с несколькими N метками в N отдельные задачm с двоичной классификацией с одной меткой, используя тот же базовый классификатор, который предоставляется в конструкторе.

# %%
# %%time

# using binary relevance
from skmultilearn.problem_transform import BinaryRelevance
from sklearn.naive_bayes import GaussianNB

# в качестве базового классификатора используется гаусовский наивный байесовский классификатор
classifier = BinaryRelevance(GaussianNB())

# тренировка
classifier.fit(x_train, y_train)

predictions = classifier.predict(x_test)

print("Accuracy = ",accuracy_score(y_test,predictions))
print("\n")
# Out:
# Accuracy =  0.2826086956521739
#
#
# CPU times: user 2.61 s, sys: 968 ms, total: 3.58 s
# Wall time: 3.6 s

# %% [markdown]
# ### LabelPowerset

# %% [markdown]
# http://scikit.ml/api/skmultilearn.problem_transform.lp.html#skmultilearn.problem_transform.LabelPowerset
#
# Преобразует задачу multi-label в задачу multi-class, при этом один многоклассовый классификатор обучается по всем уникальным комбинациям меток, найденным в данных обучения.
# Этот подход учитывает возможные корреляции между метками классов. Данный классификатор имеет квадратическую скорость обучения.

# %%
# using Label Powerset
from skmultilearn.problem_transform import LabelPowerset

# %%
# %%time

classifier = LabelPowerset(LogisticRegression())

# тренировка
classifier.fit(x_train, y_train)

predictions = classifier.predict(x_test)

print("Accuracy = ",accuracy_score(y_test,predictions))
print("\n")
# Out:
# /Users/kirillvladimirov/PycharmProjects/text_classification/venv/lib/python3.7/site-packages/sklearn/linear_model/logistic.py:433: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# /Users/kirillvladimirov/PycharmProjects/text_classification/venv/lib/python3.7/site-packages/sklearn/linear_model/logistic.py:460: FutureWarning: Default multi_class will be changed to 'auto' in 0.22. Specify the multi_class option to silence this warning.
#   "this warning.", FutureWarning)
# Accuracy =  0.32608695652173914
#
#
# CPU times: user 257 ms, sys: 68.7 ms, total: 326 ms
# Wall time: 280 ms

# %% [markdown]
# ### Multilabel k Nearest Neighbours (k-ближайших соседей для multilabel)

# %% [markdown]
# http://scikit.ml/api/skmultilearn.adapt.mlknn.html#skmultilearn.adapt.MLkNN
#
# Метод k-ближайших соседей адаптированный для multilabel классификации.

# %%
from skmultilearn.adapt import MLkNN
from scipy.sparse import csr_matrix, lil_matrix

# %%
# %%time

classifier_new = MLkNN(k=10)

x_train = lil_matrix(x_train).toarray()
y_train = lil_matrix(y_train).toarray()
x_test = lil_matrix(x_test).toarray()

classifier_new.fit(x_train, y_train)

predictions_new = classifier_new.predict(x_test)

print("Accuracy = ",accuracy_score(y_test,predictions_new))
print("\n")
# Out:
# Accuracy =  0.391304347826087
#
#
# CPU times: user 1.23 s, sys: 46.8 ms, total: 1.28 s
# Wall time: 1.06 s

# %% [markdown]
# Для проведения качественного обучения обучающая выборка крайне мала. Для улучшения качества результата я бы расширил корпус данными из других аналогичных источников.
# Так же, для решения проблемы классификации можно алгоритмы глубокого обучения.

# %% [markdown]
# ### Сохранение обученной модели

# %%
import pickle

# %%
model = classifier_new

# %%
pkl_filename = "pickle_model.pkl"  
with open(pkl_filename, 'wb') as file:  
    pickle.dump(model, file)

# %% [markdown]
# Загрузка модели из файла

# %%
with open(pkl_filename, 'rb') as file:  
    pickle_model = pickle.load(file)

# %% [markdown]
# Расчет точности и предсказание результата

# %%
score = pickle_model.score(x_test, y_test)  
print("Test score: {0:.2f} %".format(100 * score))  
Ypredict = pickle_model.predict(x_test)
# Out:
# Test score: 39.13 %
